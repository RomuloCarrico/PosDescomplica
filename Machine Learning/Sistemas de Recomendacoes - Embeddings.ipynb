# %%
# Importando a biblioteca e as funções necessárias

import nltk
from gensim.models import Word2Vec
from nltk.corpus import stopwords

# %% [markdown]
# Texto utilizado para treinamento do algoritmo foi retirado da página de Monarquia do Reino Unido do Wikipedia(https://pt.wikipedia.org/wiki/Monarquia_do_Reino_Unido) no dia 16/11/2023.
# A monarquia do Reino Unido, comumente chamada de monarquia britânica, é a monarquia constitucional do Reino Unido e seus territórios ultramarinos. O título do monarca é "rei" (homem) ou "rainha" (mulher). O atual monarca é Carlos III, que ascendeu ao trono em 8 de setembro de 2022 após a morte da rainha, Isabel II.
#
# O monarca e sua família imediata realizam várias funções oficiais, cerimoniais, diplomáticas e representativas e convocar o Parlamento e dissolve-lo. Como monarca constitucional, ele ou ela está limitado a funções apartidárias como a outorgação de honras e nomeação do primeiro-ministro. O monarca é tradicionalmente comandante em chefe das Forças Armadas Britânicas. Apesar da última autoridade formal executiva do governo do Reino Unido ainda ser através da prerrogativa real do monarca, esses poderes podem ser usados apenas de acordo com as leis promulgadas pelo parlamento e, na prática, dentro das restrições de convenções e precedentes.
#
# A monarquia britânica traça suas origens nos pequenos reinos da Escócia na alta idade média e os da Inglaterra anglo-saxã, que consolidaram-se nos reinos da Inglaterra e Escócia por volta do século X. O último monarca anglo-saxão, Haroldo II, foi derrotado e morto em 1066 durante a conquista normanda da Inglaterra e assim a monarquia inglesa passou para o normando Guilherme, o Conquistador, e seus descendentes.
#
# O norte do País de Gales, como principado, virou um estado cliente da Inglaterra no século XIII, enquanto a Magna Carta começou um processo de reduzir os poderes políticos do monarca.
#
# Os reinos da Inglaterra e Escócia passaram a ser governados por um único soberano a partir de 1603, quando o rei Jaime VI da Escócia herdou o trono inglês como Jaime I. De 1649 a 1660, a tradição da monarquia foi quebrada pela republicana Comunidade da Inglaterra, que estabeleceu-se depois da Guerra Civil Inglesa. O Decreto de Estabelecimento de 1701, que ainda está em vigor, excluiu católicos, ou aqueles casados com católicos, da linha de sucessão. Os reinos da Inglaterra e Escócia foram unidos em 1707 no Reino da Grã-Bretanha, e em 1801 o Reino da Irlanda se uniu para criar o Reino Unido da Grã-Bretanha e Irlanda. O monarca britânico tornou-se o chefe nominal do vasto Império Britânico, que cobriu um quarto da superfície da Terra em sua maior extensão no ano de 1921.
#
# A maior parte da Irlanda separou-se da união na década de 1920 como o Estado Livre Irlandês, com a Declaração Balfour reconhecendo a evolução dos domínios do império em países separados e com governos próprios dentro Commonwealth. Depois da Segunda Guerra Mundial, a maioria das colônias e territórios britânicos tornou-se independentes, efetivamente encerrando o império. Jorge VI e sua sucessora Isabel II adotaram o título de Chefe da Comunidade Britânica como símbolo da livre associação de estados independentes.
#
# O Reino Unido e quinze outras monarquias da Commonwealth partilham a mesma pessoa como seu monarca e são chamados de Reinos da Comunidade de Nações. Os termos "monarquia britânica" e "monarca britânico" são frequentemente empregados em referência à pessoa ou à instituição; entretanto, cada país é soberano e independente do outro, com o monarca tendo um título e estilo específico e nacional em cada reino.

# %%
# Salvando o texto que será utilizado para treinar o 
# algoritmo em uma variável
texto = """A monarquia do Reino Unido, comumente chamada de monarquia britânica, é a monarquia constitucional do Reino Unido e seus territórios ultramarinos. O título do monarca é "rei" (homem) ou "rainha" (mulher). O atual monarca é Carlos III, que ascendeu ao trono em 8 de setembro de 2022 após a morte da rainha, Isabel II.

O monarca e sua família imediata realizam várias funções oficiais, cerimoniais, diplomáticas e representativas e convocar o Parlamento e dissolve-lo. Como monarca constitucional, ele ou ela está limitado a funções apartidárias como a outorgação de honras e nomeação do primeiro-ministro. O monarca é tradicionalmente comandante em chefe das Forças Armadas Britânicas. Apesar da última autoridade formal executiva do governo do Reino Unido ainda ser através da prerrogativa real do monarca, esses poderes podem ser usados apenas de acordo com as leis promulgadas pelo parlamento e, na prática, dentro das restrições de convenções e precedentes.

A monarquia britânica traça suas origens nos pequenos reinos da Escócia na alta idade média e os da Inglaterra anglo-saxã, que consolidaram-se nos reinos da Inglaterra e Escócia por volta do século X. O último monarca anglo-saxão, Haroldo II, foi derrotado e morto em 1066 durante a conquista normanda da Inglaterra e assim a monarquia inglesa passou para o normando Guilherme, o Conquistador, e seus descendentes.

O norte do País de Gales, como principado, virou um estado cliente da Inglaterra no século XIII, enquanto a Magna Carta começou um processo de reduzir os poderes políticos do monarca.

Os reinos da Inglaterra e Escócia passaram a ser governados por um único soberano a partir de 1603, quando o rei Jaime VI da Escócia herdou o trono inglês como Jaime I. De 1649 a 1660, a tradição da monarquia foi quebrada pela republicana Comunidade da Inglaterra, que estabeleceu-se depois da Guerra Civil Inglesa. O Decreto de Estabelecimento de 1701, que ainda está em vigor, excluiu católicos, ou aqueles casados com católicos, da linha de sucessão. Os reinos da Inglaterra e Escócia foram unidos em 1707 no Reino da Grã-Bretanha, e em 1801 o Reino da Irlanda se uniu para criar o Reino Unido da Grã-Bretanha e Irlanda. O monarca britânico tornou-se o chefe nominal do vasto Império Britânico, que cobriu um quarto da superfície da Terra em sua maior extensão no ano de 1921.

A maior parte da Irlanda separou-se da união na década de 1920 como o Estado Livre Irlandês, com a Declaração Balfour reconhecendo a evolução dos domínios do império em países separados e com governos próprios dentro Commonwealth. Depois da Segunda Guerra Mundial, a maioria das colônias e territórios britânicos tornou-se independentes, efetivamente encerrando o império. Jorge VI e sua sucessora Isabel II adotaram o título de Chefe da Comunidade Britânica como símbolo da livre associação de estados independentes.

O Reino Unido e quinze outras monarquias da Commonwealth partilham a mesma pessoa como seu monarca e são chamados de Reinos da Comunidade de Nações. Os termos "monarquia britânica" e "monarca britânico" são frequentemente empregados em referência à pessoa ou à instituição; entretanto, cada país é soberano e independente do outro, com o monarca tendo um título e estilo específico e nacional em cada reino."""

# %%
# Download de algoritmo para tokenizar a string
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\romul\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# Transformando o texto em uma lista de frases
frases = nltk.sent_tokenize(texto)
frases
# Out:
# ['A monarquia do Reino Unido, comumente chamada de monarquia britânica, é a monarquia constitucional do Reino Unido e seus territórios ultramarinos.',
#  'O título do monarca é "rei" (homem) ou "rainha" (mulher).',
#  'O atual monarca é Carlos III, que ascendeu ao trono em 8 de setembro de 2022 após a morte da rainha, Isabel II.',
#  'O monarca e sua família imediata realizam várias funções oficiais, cerimoniais, diplomáticas e representativas e convocar o Parlamento e dissolve-lo.',
#  'Como monarca constitucional, ele ou ela está limitado a funções apartidárias como a outorgação de honras e nomeação do primeiro-ministro.',
#  'O monarca é tradicionalmente comandante em chefe das Forças Armadas Britânicas.',
#  'Apesar da última autoridade formal executiva do governo do Reino Unido ainda ser através da prerrogativa real do monarca, esses poderes podem ser usados apenas de acordo com as leis promulgadas pelo parlamento e, na prática, dentro das restrições de convenções e precedentes.',
#  'A monarquia britânica traça suas origens nos pequenos reinos da Escócia na alta idade média e os da Inglaterra anglo-saxã, que consolidaram-se nos reinos da Inglaterra e Escócia por volta do século X. O último monarca anglo-saxão, Haroldo II, foi derrotado e morto em 1066 durante a conquista normanda da Inglaterra e assim a monarquia inglesa passou para o normando Guilherme, o Conquistador, e seus descendentes.',
#  'O norte do País de Gales, como principado, virou um estado cliente da Inglaterra no século XIII, enquanto a Magna Carta começou um processo de reduzir os poderes políticos do monarca.',
#  'Os reinos da Inglaterra e Escócia passaram a ser governados por um único soberano a partir de 1603, quando o rei Jaime VI da Escócia herdou o trono inglês como Jaime I.',
#  'De 1649 a 1660, a tradição da monarquia foi quebrada pela republicana Comunidade da Inglaterra, que estabeleceu-se depois da Guerra Civil Inglesa.',
#  'O Decreto de Estabelecimento de 1701, que ainda está em vigor, excluiu católicos, ou aqueles casados com católicos, da linha de sucessão.',
#  'Os reinos da Inglaterra e Escócia foram unidos em 1707 no Reino da Grã-Bretanha, e em 1801 o Reino da Irlanda se uniu para criar o Reino Unido da Grã-Bretanha e Irlanda.',
#  'O monarca britânico tornou-se o chefe nominal do vasto Império Britânico, que cobriu um quarto da superfície da Terra em sua maior extensão no ano de 1921.',
#  'A maior parte da Irlanda separou-se da união na década de 1920 como o Estado Livre Irlandês, com a Declaração Balfour reconhecendo a evolução dos domínios do império em países separados e com governos próprios dentro Commonwealth.',
#  'Depois da Segunda Guerra Mundial, a maioria das colônias e territórios britânicos tornou-se independentes, efetivamente encerrando o império.',
#  'Jorge VI e sua sucessora Isabel II adotaram o título de Chefe da Comunidade Britânica como símbolo da livre associação de estados independentes.',
#  'O Reino Unido e quinze outras monarquias da Commonwealth partilham a mesma pessoa como seu monarca e são chamados de Reinos da Comunidade de Nações.',
#  'Os termos "monarquia britânica" e "monarca britânico" são frequentemente empregados em referência à pessoa ou à instituição; entretanto, cada país é soberano e independente do outro, com o monarca tendo um título e estilo específico e nacional em cada reino.']

# %%
# Transformado cada frase em uma lista de palavras

palavras = [nltk.word_tokenize(frases) for frases in frases]
palavras
# Out:
# [['A',
#   'monarquia',
#   'do',
#   'Reino',
#   'Unido',
#   ',',
#   'comumente',
#   'chamada',
#   'de',
#   'monarquia',
#   'britânica',
#   ',',
#   'é',
#   'a',
#   'monarquia',
#   'constitucional',
#   'do',
#   'Reino',
#   'Unido',
#   'e',
#   'seus',
#   'territórios',
#   'ultramarinos',
#   '.'],
#  ['O',
#   'título',
#   'do',
#   'monarca',
#   'é',
#   '``',
#   'rei',
#   "''",
#   '(',
#   'homem',
#   ')',
#   'ou',
#   '``',
#   'rainha',
#   "''",
#   '(',
#   'mulher',
#   ')',
#   '.'],
#  ['O',
#   'atual',
#   'monarca',
#   'é',
#   'Carlos',
#   'III',
#   ',',
#   'que',
#   'ascendeu',
#   'ao',
#   'trono',
#   'em',
#   '8',
#   'de',
#   'setembro',
#   'de',
#   '2022',
#   'após',
#   'a',
#   'morte',
#   'da',
#   'rainha',
#   ',',
#   'Isabel',
#   'II',
#   '.'],
#  ['O',
#   'monarca',
#   'e',
#   'sua',
#   'família',
#   'imediata',
#   'realizam',
#   'várias',
#   'funções',
#   'oficiais',
#   ',',
#   'cerimoniais',
#   ',',
#   'diplomáticas',
#   'e',
#   'representativas',
#   'e',
#   'convocar',
#   'o',
#   'Parlamento',
#   'e',
#   'dissolve-lo',
#   '.'],
#  ['Como',
#   'monarca',
#   'constitucional',
#   ',',
#   'ele',
#   'ou',
#   'ela',
#   'está',
#   'limitado',
#   'a',
#   'funções',
#   'apartidárias',
#   'como',
#   'a',
#   'outorgação',
#   'de',
#   'honras',
#   'e',
#   'nomeação',
#   'do',
#   'primeiro-ministro',
#   '.'],
#  ['O',
#   'monarca',
#   'é',
#   'tradicionalmente',
#   'comandante',
#   'em',
#   'chefe',
#   'das',
#   'Forças',
#   'Armadas',
#   'Britânicas',
#   '.'],
#  ['Apesar',
#   'da',
#   'última',
#   'autoridade',
#   'formal',
#   'executiva',
#   'do',
#   'governo',
#   'do',
#   'Reino',
#   'Unido',
#   'ainda',
#   'ser',
#   'através',
#   'da',
#   'prerrogativa',
#   'real',
#   'do',
#   'monarca',
#   ',',
#   'esses',
#   'poderes',
#   'podem',
#   'ser',
#   'usados',
#   'apenas',
#   'de',
#   'acordo',
#   'com',
#   'as',
#   'leis',
#   'promulgadas',
#   'pelo',
#   'parlamento',
#   'e',
#   ',',
#   'na',
#   'prática',
#   ',',
#   'dentro',
#   'das',
#   'restrições',
#   'de',
#   'convenções',
#   'e',
#   'precedentes',
#   '.'],
#  ['A',
#   'monarquia',
#   'britânica',
#   'traça',
#   'suas',
#   'origens',
#   'nos',
#   'pequenos',
#   'reinos',
#   'da',
#   'Escócia',
#   'na',
#   'alta',
#   'idade',
#   'média',
#   'e',
#   'os',
#   'da',
#   'Inglaterra',
#   'anglo-saxã',
#   ',',
#   'que',
#   'consolidaram-se',
#   'nos',
#   'reinos',
#   'da',
#   'Inglaterra',
#   'e',
#   'Escócia',
#   'por',
#   'volta',
#   'do',
#   'século',
#   'X.',
#   'O',
#   'último',
#   'monarca',
#   'anglo-saxão',
#   ',',
#   'Haroldo',
#   'II',
#   ',',
#   'foi',
#   'derrotado',
#   'e',
#   'morto',
#   'em',
#   '1066',
#   'durante',
#   'a',
#   'conquista',
#   'normanda',
#   'da',
#   'Inglaterra',
#   'e',
#   'assim',
#   'a',
#   'monarquia',
#   'inglesa',
#   'passou',
#   'para',
#   'o',
#   'normando',
#   'Guilherme',
#   ',',
#   'o',
#   'Conquistador',
#   ',',
#   'e',
#   'seus',
#   'descendentes',
#   '.'],
#  ['O',
#   'norte',
#   'do',
#   'País',
#   'de',
#   'Gales',
#   ',',
#   'como',
#   'principado',
#   ',',
#   'virou',
#   'um',
#   'estado',
#   'cliente',
#   'da',
#   'Inglaterra',
#   'no',
#   'século',
#   'XIII',
#   ',',
#   'enquanto',
#   'a',
#   'Magna',
#   'Carta',
#   'começou',
#   'um',
#   'processo',
#   'de',
#   'reduzir',
#   'os',
#   'poderes',
#   'políticos',
#   'do',
#   'monarca',
#   '.'],
#  ['Os',
#   'reinos',
#   'da',
#   'Inglaterra',
#   'e',
#   'Escócia',
#   'passaram',
#   'a',
#   'ser',
#   'governados',
#   'por',
#   'um',
#   'único',
#   'soberano',
#   'a',
#   'partir',
#   'de',
#   '1603',
#   ',',
#   'quando',
#   'o',
#   'rei',
#   'Jaime',
#   'VI',
#   'da',
#   'Escócia',
#   'herdou',
#   'o',
#   'trono',
#   'inglês',
#   'como',
#   'Jaime',
#   'I',
#   '.'],
#  ['De',
#   '1649',
#   'a',
#   '1660',
#   ',',
#   'a',
#   'tradição',
#   'da',
#   'monarquia',
#   'foi',
#   'quebrada',
#   'pela',
#   'republicana',
#   'Comunidade',
#   'da',
#   'Inglaterra',
#   ',',
#   'que',
#   'estabeleceu-se',
#   'depois',
#   'da',
#   'Guerra',
#   'Civil',
#   'Inglesa',
#   '.'],
#  ['O',
#   'Decreto',
#   'de',
#   'Estabelecimento',
#   'de',
#   '1701',
#   ',',
#   'que',
#   'ainda',
#   'está',
#   'em',
#   'vigor',
#   ',',
#   'excluiu',
#   'católicos',
#   ',',
#   'ou',
#   'aqueles',
#   'casados',
#   'com',
#   'católicos',
#   ',',
#   'da',
#   'linha',
#   'de',
#   'sucessão',
#   '.'],
#  ['Os',
#   'reinos',
#   'da',
#   'Inglaterra',
#   'e',
#   'Escócia',
#   'foram',
#   'unidos',
#   'em',
#   '1707',
#   'no',
#   'Reino',
#   'da',
#   'Grã-Bretanha',
#   ',',
#   'e',
#   'em',
#   '1801',
#   'o',
#   'Reino',
#   'da',
#   'Irlanda',
#   'se',
#   'uniu',
#   'para',
#   'criar',
#   'o',
#   'Reino',
#   'Unido',
#   'da',
#   'Grã-Bretanha',
#   'e',
#   'Irlanda',
#   '.'],
#  ['O',
#   'monarca',
#   'britânico',
#   'tornou-se',
#   'o',
#   'chefe',
#   'nominal',
#   'do',
#   'vasto',
#   'Império',
#   'Britânico',
#   ',',
#   'que',
#   'cobriu',
#   'um',
#   'quarto',
#   'da',
#   'superfície',
#   'da',
#   'Terra',
#   'em',
#   'sua',
#   'maior',
#   'extensão',
#   'no',
#   'ano',
#   'de',
#   '1921',
#   '.'],
#  ['A',
#   'maior',
#   'parte',
#   'da',
#   'Irlanda',
#   'separou-se',
#   'da',
#   'união',
#   'na',
#   'década',
#   'de',
#   '1920',
#   'como',
#   'o',
#   'Estado',
#   'Livre',
#   'Irlandês',
#   ',',
#   'com',
#   'a',
#   'Declaração',
#   'Balfour',
#   'reconhecendo',
#   'a',
#   'evolução',
#   'dos',
#   'domínios',
#   'do',
#   'império',
#   'em',
#   'países',
#   'separados',
#   'e',
#   'com',
#   'governos',
#   'próprios',
#   'dentro',
#   'Commonwealth',
#   '.'],
#  ['Depois',
#   'da',
#   'Segunda',
#   'Guerra',
#   'Mundial',
#   ',',
#   'a',
#   'maioria',
#   'das',
#   'colônias',
#   'e',
#   'territórios',
#   'britânicos',
#   'tornou-se',
#   'independentes',
#   ',',
#   'efetivamente',
#   'encerrando',
#   'o',
#   'império',
#   '.'],
#  ['Jorge',
#   'VI',
#   'e',
#   'sua',
#   'sucessora',
#   'Isabel',
#   'II',
#   'adotaram',
#   'o',
#   'título',
#   'de',
#   'Chefe',
#   'da',
#   'Comunidade',
#   'Britânica',
#   'como',
#   'símbolo',
#   'da',
#   'livre',
#   'associação',
#   'de',
#   'estados',
#   'independentes',
#   '.'],
#  ['O',
#   'Reino',
#   'Unido',
#   'e',
#   'quinze',
#   'outras',
#   'monarquias',
#   'da',
#   'Commonwealth',
#   'partilham',
#   'a',
#   'mesma',
#   'pessoa',
#   'como',
#   'seu',
#   'monarca',
#   'e',
#   'são',
#   'chamados',
#   'de',
#   'Reinos',
#   'da',
#   'Comunidade',
#   'de',
#   'Nações',
#   '.'],
#  ['Os',
#   'termos',
#   '``',
#   'monarquia',
#   'britânica',
#   "''",
#   'e',
#   '``',
#   'monarca',
#   'britânico',
#   "''",
#   'são',
#   'frequentemente',
#   'empregados',
#   'em',
#   'referência',
#   'à',
#   'pessoa',
#   'ou',
#   'à',
#   'instituição',
#   ';',
#   'entretanto',
#   ',',
#   'cada',
#   'país',
#   'é',
#   'soberano',
#   'e',
#   'independente',
#   'do',
#   'outro',
#   ',',
#   'com',
#   'o',
#   'monarca',
#   'tendo',
#   'um',
#   'título',
#   'e',
#   'estilo',
#   'específico',
#   'e',
#   'nacional',
#   'em',
#   'cada',
#   'reino',
#   '.']]

# %%
# Baixando a ferramenta do nltk para retirar as stopwords
# e importando a ferramenta

nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\romul\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
# Importando a lista de stopwords em português
# e salvando em uma lista
stopwords_portugues = stopwords.words('portuguese')
stopwords_portugues
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
# Fazendo a remoção das stopwords

for i in range(len(palavras)):
    palavras_loop = []
    for palavra in palavras[i]:
        if palavra.lower() not in stopwords_portugues:
            palavras_loop.append(palavra.lower())
        palavras[i] = palavras_loop

# %%
palavras
# Out:
# [['monarquia',
#   'reino',
#   'unido',
#   ',',
#   'comumente',
#   'chamada',
#   'monarquia',
#   'britânica',
#   ',',
#   'monarquia',
#   'constitucional',
#   'reino',
#   'unido',
#   'territórios',
#   'ultramarinos',
#   '.'],
#  ['título',
#   'monarca',
#   '``',
#   'rei',
#   "''",
#   '(',
#   'homem',
#   ')',
#   '``',
#   'rainha',
#   "''",
#   '(',
#   'mulher',
#   ')',
#   '.'],
#  ['atual',
#   'monarca',
#   'carlos',
#   'iii',
#   ',',
#   'ascendeu',
#   'trono',
#   '8',
#   'setembro',
#   '2022',
#   'após',
#   'morte',
#   'rainha',
#   ',',
#   'isabel',
#   'ii',
#   '.'],
#  ['monarca',
#   'família',
#   'imediata',
#   'realizam',
#   'várias',
#   'funções',
#   'oficiais',
#   ',',
#   'cerimoniais',
#   ',',
#   'diplomáticas',
#   'representativas',
#   'convocar',
#   'parlamento',
#   'dissolve-lo',
#   '.'],
#  ['monarca',
#   'constitucional',
#   ',',
#   'limitado',
#   'funções',
#   'apartidárias',
#   'outorgação',
#   'honras',
#   'nomeação',
#   'primeiro-ministro',
#   '.'],
#  ['monarca',
#   'tradicionalmente',
#   'comandante',
#   'chefe',
#   'forças',
#   'armadas',
#   'britânicas',
#   '.'],
#  ['apesar',
#   'última',
#   'autoridade',
#   'formal',
#   'executiva',
#   'governo',
#   'reino',
#   'unido',
#   'ainda',
#   'através',
#   'prerrogativa',
#   'real',
#   'monarca',
#   ',',
#   'poderes',
#   'podem',
#   'usados',
#   'apenas',
#   'acordo',
#   'leis',
#   'promulgadas',
#   'parlamento',
#   ',',
#   'prática',
#   ',',
#   'dentro',
#   'restrições',
#   'convenções',
#   'precedentes',
#   '.'],
#  ['monarquia',
#   'britânica',
#   'traça',
#   'origens',
#   'pequenos',
#   'reinos',
#   'escócia',
#   'alta',
#   'idade',
#   'média',
#   'inglaterra',
#   'anglo-saxã',
#   ',',
#   'consolidaram-se',
#   'reinos',
#   'inglaterra',
#   'escócia',
#   'volta',
#   'século',
#   'x.',
#   'último',
#   'monarca',
#   'anglo-saxão',
#   ',',
#   'haroldo',
#   'ii',
#   ',',
#   'derrotado',
#   'morto',
#   '1066',
#   'durante',
#   'conquista',
#   'normanda',
#   'inglaterra',
#   'assim',
#   'monarquia',
#   'inglesa',
#   'passou',
#   'normando',
#   'guilherme',
#   ',',
#   'conquistador',
#   ',',
#   'descendentes',
#   '.'],
#  ['norte',
#   'país',
#   'gales',
#   ',',
#   'principado',
#   ',',
#   'virou',
#   'estado',
#   'cliente',
#   'inglaterra',
#   'século',
#   'xiii',
#   ',',
#   'enquanto',
#   'magna',
#   'carta',
#   'começou',
#   'processo',
#   'reduzir',
#   'poderes',
#   'políticos',
#   'monarca',
#   '.'],
#  ['reinos',
#   'inglaterra',
#   'escócia',
#   'passaram',
#   'governados',
#   'único',
#   'soberano',
#   'partir',
#   '1603',
#   ',',
#   'rei',
#   'jaime',
#   'vi',
#   'escócia',
#   'herdou',
#   'trono',
#   'inglês',
#   'jaime',
#   'i',
#   '.'],
#  ['1649',
#   '1660',
#   ',',
#   'tradição',
#   'monarquia',
#   'quebrada',
#   'republicana',
#   'comunidade',
#   'inglaterra',
#   ',',
#   'estabeleceu-se',
#   'guerra',
#   'civil',
#   'inglesa',
#   '.'],
#  ['decreto',
#   'estabelecimento',
#   '1701',
#   ',',
#   'ainda',
#   'vigor',
#   ',',
#   'excluiu',
#   'católicos',
#   ',',
#   'casados',
#   'católicos',
#   ',',
#   'linha',
#   'sucessão',
#   '.'],
#  ['reinos',
#   'inglaterra',
#   'escócia',
#   'unidos',
#   '1707',
#   'reino',
#   'grã-bretanha',
#   ',',
#   '1801',
#   'reino',
#   'irlanda',
#   'uniu',
#   'criar',
#   'reino',
#   'unido',
#   'grã-bretanha',
#   'irlanda',
#   '.'],
#  ['monarca',
#   'britânico',
#   'tornou-se',
#   'chefe',
#   'nominal',
#   'vasto',
#   'império',
#   'britânico',
#   ',',
#   'cobriu',
#   'quarto',
#   'superfície',
#   'terra',
#   'maior',
#   'extensão',
#   'ano',
#   '1921',
#   '.'],
#  ['maior',
#   'parte',
#   'irlanda',
#   'separou-se',
#   'união',
#   'década',
#   '1920',
#   'estado',
#   'livre',
#   'irlandês',
#   ',',
#   'declaração',
#   'balfour',
#   'reconhecendo',
#   'evolução',
#   'domínios',
#   'império',
#   'países',
#   'separados',
#   'governos',
#   'próprios',
#   'dentro',
#   'commonwealth',
#   '.'],
#  ['segunda',
#   'guerra',
#   'mundial',
#   ',',
#   'maioria',
#   'colônias',
#   'territórios',
#   'britânicos',
#   'tornou-se',
#   'independentes',
#   ',',
#   'efetivamente',
#   'encerrando',
#   'império',
#   '.'],
#  ['jorge',
#   'vi',
#   'sucessora',
#   'isabel',
#   'ii',
#   'adotaram',
#   'título',
#   'chefe',
#   'comunidade',
#   'britânica',
#   'símbolo',
#   'livre',
#   'associação',
#   'estados',
#   'independentes',
#   '.'],
#  ['reino',
#   'unido',
#   'quinze',
#   'outras',
#   'monarquias',
#   'commonwealth',
#   'partilham',
#   'mesma',
#   'pessoa',
#   'monarca',
#   'chamados',
#   'reinos',
#   'comunidade',
#   'nações',
#   '.'],
#  ['termos',
#   '``',
#   'monarquia',
#   'britânica',
#   "''",
#   '``',
#   'monarca',
#   'britânico',
#   "''",
#   'frequentemente',
#   'empregados',
#   'referência',
#   'pessoa',
#   'instituição',
#   ';',
#   'entretanto',
#   ',',
#   'cada',
#   'país',
#   'soberano',
#   'independente',
#   'outro',
#   ',',
#   'monarca',
#   'tendo',
#   'título',
#   'estilo',
#   'específico',
#   'nacional',
#   'cada',
#   'reino',
#   '.']]

# %%
# Instanciando o Word2Vec, treinando com o vetor de palavras
# e salvando o embedding numa nova variável

modelo = Word2Vec(palavras, min_count=1)

vetor_palavras = modelo.wv

# %%
vetor_palavras.most_similar("monarca")
# Out:
# [('volta', 0.37562015652656555),
#  ('inglesa', 0.21497805416584015),
#  ('encerrando', 0.20620949566364288),
#  ('origens', 0.20513732731342316),
#  ('reinos', 0.20447222888469696),
#  ('superfície', 0.2014971226453781),
#  ('ano', 0.2006794661283493),
#  ('inglês', 0.198074072599411),
#  ('várias', 0.19041737914085388),
#  ('i', 0.18743525445461273)]

# %%
vetor_palavras.most_similar("reino")
# Out:
# [('1801', 0.2982999384403229),
#  ('quinze', 0.272742360830307),
#  ('países', 0.25524717569351196),
#  ('outro', 0.22159318625926971),
#  ('específico', 0.21587713062763214),
#  ('derrotado', 0.20509640872478485),
#  ('após', 0.1850663423538208),
#  ('chefe', 0.17737101018428802),
#  ('x.', 0.1671958714723587),
#  ('passaram', 0.1662963628768921)]
